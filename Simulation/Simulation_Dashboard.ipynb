# %%
# %load_ext autoreload
# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

from Models import Model

import pandas as pd

# %%
m = Model()
dir(m)
# Out:
# No csv-path given, loading from default data/pv_1kWp.csv...
# ['ACH_I',
#  'ACH_V',
#  'Btt_to_ED',
#  'ED',
#  'ED_QC',
#  'ED_QH',
#  'ED_grid',
#  'ED_user',
#  'PV',
#  'PV_feedin',
#  'PV_prod',
#  'PV_to_battery',
#  'PV_use',
#  'QC',
#  'QH',
#  'QI',
#  'QI_summer',
#  'QI_winter',
#  'QS',
#  'QT',
#  'QV',
#  'Q_loss',
#  'Qdhw',
#  'TA',
#  'TI',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'battery',
#  'building',
#  'calc_ED',
#  'calc_ED_QC',
#  'calc_ED_QH',
#  'calc_PV_use',
#  'calc_QC',
#  'calc_QH',
#  'calc_QT',
#  'calc_QV',
#  'calc_TI',
#  'calc_battery_use',
#  'calc_cost',
#  'config',
#  'init_sim',
#  'is_cooling_on',
#  'is_heating_on',
#  'plot',
#  'plot_ED',
#  'plot_ES',
#  'plot_Q',
#  'plot_T',
#  'plot_overview',
#  'simulate',
#  'timestamp']

# %%
m.simulate()
# Out:
# Investment cost:              16000.00 €
# Operational cost:              9623.00 €/annum
# Total cost after 20 years:  208,452.00 €
# True

# %%
m.QT
# Out:
# array([  0.        , -11.91587719,  -7.96874287, ..., -16.45880537,
#        -16.34709402, -16.08643421])

# %%
m.plot()
# Out:
# C:\Users\Simon Schneider\PycharmProjects\MEE-BB-2-SS2021-AS-Simulation\Simulation\Models.py:352: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
plt.plot(m.QT)
